# %%
# %run /home/xzhoubi/hudson/VAE_baselines/train_mnist.py --z_dim 100 --epochs 200 --architecture dc_vae --data_set ColoredMNIST --x_dis Logistic
# Out:
# /import/home/xzhoubi/hudson/VAE_baselines
# Colored MNIST dataset already exists
# Colored MNIST dataset already exists
# 100%|█████████████████████████████████████████████████████████████████████| 200/200 [00:17<00:00, 11.33it/s]
#  Epoch 0: Label Accuracy is 24.739999771118164% Color Accuracy is 80.35250091552734%
#  Epoch 0: Loss is 1822.214599609375
# 100%|█████████████████████████████████████████████████████████████████████| 200/200 [00:19<00:00, 10.40it/s]
#  Epoch 1: Label Accuracy is 78.37999725341797% Color Accuracy is 99.85250091552734%
#  Epoch 1: Loss is 1601.464111328125
# 100%|█████████████████████████████████████████████████████████████████████| 200/200 [00:14<00:00, 13.90it/s]
#  Epoch 2: Label Accuracy is 92.70999908447266% Color Accuracy is 99.98500061035156%
#  Epoch 2: Loss is 1448.4117431640625
# 100%|█████████████████████████████████████████████████████████████████████| 200/200 [00:15<00:00, 13.04it/s]
# ...

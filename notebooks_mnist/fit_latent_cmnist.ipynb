# %%
# %run /home/xzhoubi/hudson/VAE_baselines/fit_z.py --architecture vae --z_channels 2 --log_freq 5 --loss elbo --data_set ColoredMNIST --path ./save/ColoredMNIST/architecture_dc_vae__alpha_1.0/ --x_dis Logistic
# Out:
# Done loading pretrained latent block data
# Done loading pretrained latent block data
# ...
# 100%|████████████████████████████████████████████████████████████████████| 400/400 [00:02<00:00, 156.01it/s]

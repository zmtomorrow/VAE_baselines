# %%
# %run /home/xzhoubi/hudson/VAE_baselines/fit_z.py --architecture vae --z_channels 2 --log_freq 5 --loss elbo --path ./save/BinaryMNIST/architecture_dc_vae__alpha_1.0/
# Out:
# Done loading pretrained latent block data
# Done loading pretrained latent block data
# ...
# 100%|████████████████████████████████████████████████████████████████████| 600/600 [00:03<00:00, 166.15it/s]

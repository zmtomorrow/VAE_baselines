# %%
# %run /home/xzhoubi/hudson/VAE_baselines/fit_prior.py --architecture rnn --z_channels 2 --log_freq 5 --loss mean --lr 1e-4
# Out:
# Loading latent block data
# Done loading latent block data
# Loading latent block data
# Done loading latent block data
# ...
#  21%|█████████████████████████████▌                                                                                                            | 107/500 [00:03<00:12, 32.34it/s]

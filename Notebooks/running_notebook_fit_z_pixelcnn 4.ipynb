# %%
# %run /home/xzhoubi/hudson/VAE_baselines/fit_z.py --architecture pixelcnn --z_channels 2 --log_freq 2 --mixture_num 2 --loss mixture_of_gaussian
# Out:
# Done loading pretrained latent block data
# Done loading pretrained latent block data
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:40<00:00, 12.34it/s]

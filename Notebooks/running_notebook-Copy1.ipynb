# %%
# %run /home/xzhoubi/hudson/VAE_baselines/fit_prior.py
# Out:
# Loading latent block data
# Done loading latent block data
# Loading latent block data
# Done loading latent block data
# ...
#  91%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████             | 453/500 [03:10<00:19,  2.39it/s]

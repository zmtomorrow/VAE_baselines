# %%
# %run /home/xzhoubi/hudson/VAE_baselines/fit_prior.py --architecture rnn --z_channels 2 --log_freq 5 --loss reverse_kl --lr 1e-4
# Out:
# Loading latent block data
# Done loading latent block data
# Loading latent block data
# Done loading latent block data
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:17<00:00, 28.80it/s]

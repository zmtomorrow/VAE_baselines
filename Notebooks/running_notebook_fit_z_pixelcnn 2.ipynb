# %%
# %run /home/xzhoubi/hudson/VAE_baselines/fit_prior.py --architecture pixelcnn --z_channels 2 --log_freq 2 --loss reverse_kl
# Out:
# Loading latent block data
# Done loading latent block data
# Loading latent block data
# Done loading latent block data
# ...
#  47%|█████████████████████████████████████████████████████████████████▍                                                                        | 237/500 [00:15<00:21, 12.15it/s]

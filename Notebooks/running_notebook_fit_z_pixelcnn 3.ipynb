# %%
# %run /home/xzhoubi/hudson/VAE_baselines/fit_z.py --architecture pixelcnn --z_channels 2 --log_freq 2 --loss forward_kl
# Out:
# Loading latent block data
# Done loading latent block data
# Loading latent block data
# Done loading latent block data
# ...
#  63%|███████████████████████████████████████████████████████████████████████████████████████▏                                                  | 316/500 [00:13<00:09, 19.60it/s]

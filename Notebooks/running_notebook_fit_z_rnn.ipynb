# %%
# %run /home/xzhoubi/hudson/VAE_baselines/fit_z.py --architecture rnn --z_channels 2 --log_freq 2 --loss forward_kl --lr 1e-4
# Out:
# Loading latent block data
# Done loading latent block data
# Loading latent block data
# Done loading latent block data
# ...
#  11%|███████████████                                                                                                                            | 54/500 [00:01<00:12, 36.04it/s]
